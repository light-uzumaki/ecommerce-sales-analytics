# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/final_dataset.csv")

print(df.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  month  year  ... payment_installments  \
# 0           2017-10-18 00:00:00     10  2017  ...                  1.0
# 1           2017-10-18 00:00:00     10  2017  ...                  1.0
# 2           2017-10-18 00:00:00     10  2017  ...                  1.0
# 3           2018-08-13 00:00:00      7  2018  ...                  1.0
# 4           2018-09-04 00:00:00      8  2018  ...                  3.0
#
#    payment_value  product_category_name product_name_lenght  \
# 0          18.12  utilidades_domesticas                40.0
# 1           2.00  utilidades_domesticas                40.0
# 2          18.59  utilidades_domesticas                40.0
# 3         141.46             perfumaria                29.0
# 4         179.12             automotivo                46.0
#
#    product_description_lenght product_photos_qty product_weight_g  \
# 0                       268.0                4.0            500.0
# 1                       268.0                4.0            500.0
# 2                       268.0                4.0            500.0
# 3                       178.0                1.0            400.0
# 4                       232.0                1.0            420.0
#
#   product_length_cm  product_height_cm  product_width_cm
# 0              19.0                8.0              13.0
# 1              19.0                8.0              13.0
# 2              19.0                8.0              13.0
# 3              19.0               13.0              19.0
# 4              24.0               19.0              21.0
#
# [5 rows x 32 columns]

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118434 entries, 0 to 118433
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_purchase_timestamp       118434 non-null  object
#  4   order_approved_at              118258 non-null  object
#  5   order_delivered_carrier_date   116360 non-null  object
#  6   order_delivered_customer_date  115037 non-null  object
#  7   order_estimated_delivery_date  118434 non-null  object
#  8   month                          118434 non-null  int64
#  9   year                           118434 non-null  int64
#  10  customer_unique_id             118434 non-null  object
#  11  customer_zip_code_prefix       118434 non-null  int64
#  12  customer_city                  118434 non-null  object
#  13  customer_state                 118434 non-null  object
#  14  order_item_id                  117604 non-null  float64
#  15  product_id                     117604 non-null  object
#  16  seller_id                      117604 non-null  object
#  17  shipping_limit_date            117604 non-null  object
#  18  price                          117604 non-null  float64
#  19  freight_value                  117604 non-null  float64
#  20  payment_sequential             118431 non-null  float64
#  21  payment_type                   118431 non-null  object
#  22  payment_installments           118431 non-null  float64
#  23  payment_value                  118431 non-null  float64
#  24  product_category_name          117604 non-null  object
#  25  product_name_lenght            115906 non-null  float64
#  26  product_description_lenght     115906 non-null  float64
#  27  product_photos_qty             115906 non-null  float64
#  28  product_weight_g               117584 non-null  float64
#  29  product_length_cm              117584 non-null  float64
#  30  product_height_cm              117584 non-null  float64
#  31  product_width_cm               117584 non-null  float64
# dtypes: float64(13), int64(3), object(16)
# memory usage: 28.9+ MB
# None
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 176
# order_delivered_carrier_date     2074
# order_delivered_customer_date    3397
# order_estimated_delivery_date       0
# month                               0
# year                                0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# product_category_name             830
# product_name_lenght              2528
# product_description_lenght       2528
# product_photos_qty               2528
# product_weight_g                  850
# product_length_cm                 850
# product_height_cm                 850
# product_width_cm                  850
# dtype: int64

# %%
monthly_sales = df.groupby("month")["payment_value"].sum()

monthly_sales.plot(
    kind="line",
    figsize=(10,5),
    title="Monthly Revenue"
)

plt.xlabel("Month")
plt.ylabel("Revenue")

plt.show()

# %%
top_products = df.groupby("product_id")["payment_value"] \
    .sum() \
    .sort_values(ascending=False) \
    .head(10)

print(top_products)
# Out:
# product_id
# 5769ef0a239114ac3a854af00df129e4    109312.64
# bb50f2e236e5eea0100680137654686c     81887.42
# 422879e10f46682990de24d770e7f83d     79512.22
# d1c427060a0f73f6b889a5c7c61f2ac4     70557.90
# 6cdd53843498f92890544667809f1595     64825.67
# d5991653e037ccb7af6ed7d94246b249     64143.26
# aca2eb7d00ea1a7b8ebd4e68314663af     63788.12
# a62e25e09e05e6faf31d90c6ec1aa3d1     63167.37
# 99a4788cb24856965c36a24e339b6058     63161.40
# 3dd2a17168ec895c781a9191c1e95ad7     58962.14
# Name: payment_value, dtype: float64

# %%
state_sales = df.groupby("customer_state")["payment_value"] \
    .sum() \
    .sort_values(ascending=False)

print(state_sales.head(10))
# Out:
# customer_state
# SP    7673188.55
# RJ    2783724.26
# MG    2341861.47
# RS    1152019.17
# PR    1074614.19
# BA     802416.72
# SC     799135.92
# GO     516182.51
# DF     434512.55
# ES     406946.26
# Name: payment_value, dtype: float64
